# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f_path = './output.txt'
f = open(f_path)
lines = f.readlines()

# %%
Y = []
for l in lines:
    arr = l.split()
    if len(arr) == 5:
        Y.append(float(arr[-1]))

plt.plot(Y)
plt.ylabel("loss")
plt.show()

# %%
Acc = []
for l in lines:
    arr = l.split()
    if (arr[0] == 'Accuracy'):
        Acc.append(float(arr[1]))

plt.plot(Acc)
plt.ylabel("Accuracy")
plt.show()
